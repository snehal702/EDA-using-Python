# %% [markdown]
# # EDA : Zomato Dataset

# %%
df = pd.read_csv('C:\\Users\\Snehal Sanap\\OneDrive\\Desktop\\AIML_STUDY\\INeuron\\Community Live Sessions\\Zomatodataset_EDA_Day1\\zomato.csv', encoding='latin-1')
df.head() ##encoding bcoz this dataset needs it or else error
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
df.shape
# Out:
# (9551, 21)

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
df.describe()
# Out:
#        Restaurant ID  Country Code    Longitude     Latitude  \
# count   9.551000e+03   9551.000000  9551.000000  9551.000000
# mean    9.051128e+06     18.365616    64.126574    25.854381
# std     8.791521e+06     56.750546    41.467058    11.007935
# min     5.300000e+01      1.000000  -157.948486   -41.330428
# 25%     3.019625e+05      1.000000    77.081343    28.478713
# 50%     6.004089e+06      1.000000    77.191964    28.570469
# 75%     1.835229e+07      1.000000    77.282006    28.642758
# max     1.850065e+07    216.000000   174.832089    55.976980
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9551.000000  9551.000000       9551.000000   9551.000000
# mean            1199.210763     1.804837          2.666370    156.909748
# std            16121.183073     0.905609          1.516378    430.169145
# min                0.000000     1.000000          0.000000      0.000000
# ...

# %%
df[~df.apply(np.isreal).all(1)] #no abssurd vale
# Out:
# Empty DataFrame
# Columns: [Restaurant ID, Restaurant Name, Country Code, City, Address, Locality, Locality Verbose, Longitude, Latitude, Cuisines, Average Cost for two, Currency, Has Table booking, Has Online delivery, Is delivering now, Switch to order menu, Price range, Aggregate rating, Rating color, Rating text, Votes]
# Index: []
#
# [0 rows x 21 columns]

# %%
num_cols = [i for i in df.columns if df[i].dtype!='O']
print(num_cols , len(num_cols))
# Out:
# ['Restaurant ID', 'Country Code', 'Longitude', 'Latitude', 'Average Cost for two', 'Price range', 'Aggregate rating', 'Votes'] 8

# %%
cat_cols = [i for i in df.columns if df[i].dtype=='O']
print(cat_cols , len(cat_cols))
# Out:
# ['Restaurant Name', 'City', 'Address', 'Locality', 'Locality Verbose', 'Cuisines', 'Currency', 'Has Table booking', 'Has Online delivery', 'Is delivering now', 'Switch to order menu', 'Rating color', 'Rating text'] 13

# %%
# NA VALUES and their distn in dataset
null_col =[i for i in df.columns if df[i].isnull().any()] #any na values in that particural col
#[i for i in df.columns if df[i].isnull().sum()>1]
print(null_col, len(null_col))
# Out:
# ['Cuisines'] 1

# %%
print('Cuisines : NA values: {} ({}%)'. format(df['Cuisines'].isnull().sum(),np.round(df['Cuisines'].isnull().mean(),4)))
# Out:
# Cuisines : NA values: 9 (0.0009%)

# %%
plt.figure(figsize=(15,6))
sns.heatmap(df.isnull(), yticklabels=False, cbar=True, cmap=plt.cm.viridis)
#very less values ie. 9 values in 9551 records so not visible
# Out:
# <AxesSubplot:>

# %%
df_country = pd.read_excel('C:\\Users\\Snehal Sanap\\OneDrive\\Desktop\\AIML_STUDY\\INeuron\\Community Live Sessions\\Zomatodataset_EDA_Day1\\Country-Code.xlsx')
df_country.head()
# Out:
#    Country Code    Country
# 0             1      India
# 1            14  Australia
# 2            30     Brazil
# 3            37     Canada
# 4            94  Indonesia

# %%
#now both datasets have country code in common so we will combine both of them and get in one df using pd.merge on country code variable
final_df = pd.merge(df, df_country, on= 'Country Code', how= 'left')
final_df.head() #pd.concat can also be used
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
final_df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
#Lets get some insights 
#now we see we have a col, called country which =basically tells which are the countries in which zomato is used
index = final_df.Country.value_counts().index #its tells INdia is the base of zomato more transactions happen here...bcoz US just has  a website which suggest places
#but most of transcations/ orders happen in India(base of Zomato)

# %%
values = final_df.Country.value_counts().values # tjhis gives values of num. of records for countries

# %%
#now lets create a " pie chart to DISPLAY THE TOP 3 COUNTRIES USING ZOMATO "
plt.pie(x = values[:3], labels=index[:3],autopct='%1.2f%%') #top 5 records/ countries only and % upto 2 decimal wise caluclated on values
plt.show()

# %%
#country wise count
sns.countplot(x='Country', data=final_df).set_xticklabels(sns.countplot(final_df['Country']).get_xticklabels(),rotation=90, ha="right")
plt.title('Country wise count for restaurants')
# Out:
# C:\Users\Snehal Sanap\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Country wise count for restaurants')

# %%
#Observations : 94.39% business of Zomato comes from India followed byUSA and UK

# %%
#next we see some cols for ratings so lets see from which country we get max ratings ...groupby rating cols and see records for them ...which is max rating
ratings = final_df.groupby(['Aggregate rating', 'Rating color', 'Rating text']).size().reset_index().rename(columns={0 : 'Rating_count'})
#.size gicves num of records per groubpy category 
ratings
# Out:
#     Aggregate rating Rating color Rating text  Rating_count
# 0                0.0        White   Not rated          2148
# 1                1.8          Red        Poor             1
# 2                1.9          Red        Poor             2
# 3                2.0          Red        Poor             7
# 4                2.1          Red        Poor            15
# 5                2.2          Red        Poor            27
# 6                2.3          Red        Poor            47
# 7                2.4          Red        Poor            87
# 8                2.5       Orange     Average           110
# 9                2.6       Orange     Average           191
# 10               2.7       Orange     Average           250
# 11               2.8       Orange     Average           315
# 12               2.9       Orange     Average           381
# 13               3.0       Orange     Average           468
# 14               3.1       Orange     Average           519
# ...

# %%
ratings['Rating_count'].sum()
# Out:
# 9551

# %% [markdown]
# ## some obs :
# 1. most of the ppl hhave not rated zomato app since max records show not rated
# 2. when avg ratings are b/w 4.5 - 4.9 --> Excellent service
# 3. when ratiungs b/w 4 -4.4 --> Very Good service
# 4. ratings b/w 3.5 and 3.9 --> Good sevice
# 5. ratings b/w 2.5 - 3.4 --- >average service
# 6. ratings b/w 1.8 -2.4 ---> poor service

# %%
#lets plot this obs
#which rating is given max times
plt.rcParams['figure.figsize'] =(12,6)
sns.barplot(x='Aggregate rating', y='Rating_count', data =ratings)
plt.show()

# %% [markdown]
# # Observations:
# 1. max ppl have not rated the app
# 2. except for 0 distn looks quite ND
# 3. after 0 max ppl have rated b/w 2.7 - 4.1
# 4. very few have give higher ratings
# 5. no one rated 5
# 6. this also gives us the insight that if rattings are mising in some records we can impute them we the max rating here which is b/w 2.6 -4 so we can avg them and get one value to impute

# %%
#aggreate ratings v/s rate count but hue with rate color more better visualization
sns.barplot(x='Aggregate rating', y='Rating_count', hue ='Rating color', data =ratings)
plt.show()
#it gives colour wise rating distn
#but the colours are not matching white looks like blue...so we need to map our colour labels to actual colours using palette

# %%
sns.barplot(x='Aggregate rating', y='Rating_count', hue ='Rating color', data =ratings, palette=['blue', 'red', 'orange','yellow', 'green', 'darkgreen'])
plt.show()

# %%
sns.barplot(x='Rating text', y='Rating_count', data =ratings)
plt.show() #rating text wise rarting distn

# %%
#countplot
sns.countplot(x='Rating color', data= ratings, palette=['blue', 'red', 'orange','yellow', 'green', 'darkgreen'])
plt.show()
#no. of records in ratings df for each color

# %%
sns.countplot(x='Rating text', data= ratings, hue = 'Rating color', palette=['blue', 'red', 'orange','yellow', 'green', 'darkgreen'])
plt.show()

# %%
final_df.head(3)
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
#
#                                     Locality Verbose   Longitude   Latitude  \
# 0  Century City Mall, Poblacion, Makati City, Mak...  121.027535  14.565443
# 1  Little Tokyo, Legaspi Village, Makati City, Ma...  121.014101  14.553708
# ...

# %%
country_rating = pd.DataFrame(final_df.groupby('Country')['Aggregate rating'].value_counts()).rename({'Aggregate rating' :'rating_count'}, axis=1).reset_index().sort_values(by='rating_count',ascending=False)
country_rating
# Out:
#            Country  Aggregate rating  rating_count
# 37           India               0.0          2139
# 38           India               3.1           511
# 39           India               3.2           510
# 40           India               3.4           477
# 41           India               3.3           472
# ..             ...               ...           ...
# 114          Qatar               4.9             1
# 113          Qatar               4.7             1
# 112          Qatar               4.6             1
# 110          Qatar               4.4             1
# 221  United States               2.4             1
#
# [222 rows x 3 columns]

# %%
final_df.groupby(['Aggregate rating', 'Country']).size().unstack().plot(kind='bar', stacked=True, figsize=(15, 5))
# Out:
# <AxesSubplot:xlabel='Aggregate rating'>

# %%
final_df.groupby('Country')['Aggregate rating'].size() # this gives the number of times a country rated zomato app..ie.e Austrial gave 24 diff ratings in total
# Out:
# Country
# Australia           24
# Brazil              60
# Canada               4
# India             8652
# Indonesia           21
# New Zealand         40
# Phillipines         22
# Qatar               20
# Singapore           20
# South Africa        60
# Sri Lanka           20
# Turkey              34
# UAE                 60
# United Kingdom      80
# United States      434
# Name: Aggregate rating, dtype: int64

# %%
final_df[final_df['Aggregate rating']==0]['Country'].value_counts()
#or final_df[final_df['Rating color']=='White']['Country'].value_counts()
# final_df[final_df['Rating text']=='Not rated']['Country'].value_counts()
# Out:
# India             2139
# Brazil               5
# United States        3
# United Kingdom       1
# Name: Country, dtype: int64

# %%
final_df[final_df['Aggregate rating']==0]['Country']
# Out:
# 30              Brazil
# 58              Brazil
# 69              Brazil
# 77              Brazil
# 78              Brazil
#              ...
# 9109             India
# 9110             India
# 9111             India
# 9112             India
# 9351    United Kingdom
# Name: Country, Length: 2148, dtype: object

# %%
#or
a = final_df.groupby(['Aggregate rating', 'Country']).size().reset_index().rename({0:'count'}, axis=1).head(4)
a
# Out:
#    Aggregate rating         Country  count
# 0               0.0          Brazil      5
# 1               0.0           India   2139
# 2               0.0  United Kingdom      1
# 3               0.0   United States      3

# %% [markdown]
# # Observations:
# 1. Max 0 ratyings comes from india , followed by brazil, usa, uk(mostly given when bad delivery received , no one bothers to give befor hand)

# %%
country_rating = final_df.groupby(['Aggregate rating', 'Country']).size().reset_index().rename({0:'count'}, axis=1)
country_rating
# Out:
#      Aggregate rating         Country  count
# 0                 0.0          Brazil      5
# 1                 0.0           India   2139
# 2                 0.0  United Kingdom      1
# 3                 0.0   United States      3
# 4                 1.8           India      1
# ..                ...             ...    ...
# 217               4.9       Sri Lanka      1
# 218               4.9          Turkey      3
# 219               4.9             UAE      4
# 220               4.9  United Kingdom      4
# 221               4.9   United States     14
#
# [222 rows x 3 columns]

# %%
#find out which currency is used by which country
final_df.head(3)
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
#
#                                     Locality Verbose   Longitude   Latitude  \
# 0  Century City Mall, Poblacion, Makati City, Mak...  121.027535  14.565443
# 1  Little Tokyo, Legaspi Village, Makati City, Ma...  121.014101  14.553708
# ...

# %%
final_df.groupby('Country')['Currency'].value_counts()
# Out:
# Country         Currency
# Australia       Dollar($)                   24
# Brazil          Brazilian Real(R$)          60
# Canada          Dollar($)                    4
# India           Indian Rupees(Rs.)        8652
# Indonesia       Indonesian Rupiah(IDR)      21
# New Zealand     NewZealand($)               40
# Phillipines     Botswana Pula(P)            22
# Qatar           Qatari Rial(QR)             20
# Singapore       Dollar($)                   20
# South Africa    Rand(R)                     60
# Sri Lanka       Sri Lankan Rupee(LKR)       20
# Turkey          Turkish Lira(TL)            34
# UAE             Emirati Diram(AED)          60
# United Kingdom  Pounds(£)                  80
# United States   Dollar($)                  434
# Name: Currency, dtype: int64

# %%
a = final_df.groupby(['Currency','Country']).size().reset_index().rename({0:'count'}, axis=1).sort_values(by='count', ascending=False)
a
# Out:
#                   Currency         Country  count
# 7       Indian Rupees(Rs.)           India   8652
# 5                Dollar($)   United States    434
# 10              Pounds(£)  United Kingdom     80
# 1       Brazilian Real(R$)          Brazil     60
# 6       Emirati Diram(AED)             UAE     60
# 12                 Rand(R)    South Africa     60
# 9            NewZealand($)     New Zealand     40
# 14        Turkish Lira(TL)          Turkey     34
# 2                Dollar($)       Australia     24
# 0         Botswana Pula(P)     Phillipines     22
# 8   Indonesian Rupiah(IDR)       Indonesia     21
# 4                Dollar($)       Singapore     20
# 11         Qatari Rial(QR)           Qatar     20
# 13   Sri Lankan Rupee(LKR)       Sri Lanka     20
# 3                Dollar($)          Canada      4

# %%
final_df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
#plotting the top 5 countries

# %%
##which countries do have online deliveries
final_df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
final_df['Has Online delivery'].value_counts()
# Out:
# No     7100
# Yes    2451
# Name: Has Online delivery, dtype: int64

# %%
final_df[final_df['Has Online delivery']=='Yes']['Country'].value_counts()
# Out:
# India    2423
# UAE        28
# Name: Country, dtype: int64

# %%
final_df.groupby(['Country', 'Has Online delivery']).size()
# Out:
# Country         Has Online delivery
# Australia       No                       24
# Brazil          No                       60
# Canada          No                        4
# India           No                     6229
#                 Yes                    2423
# Indonesia       No                       21
# New Zealand     No                       40
# Phillipines     No                       22
# Qatar           No                       20
# Singapore       No                       20
# South Africa    No                       60
# Sri Lanka       No                       20
# Turkey          No                       34
# UAE             No                       32
#                 Yes                      28
# United Kingdom  No                       80
# United States   No                      434
# dtype: int64

# %% [markdown]
# ## Observations:
# 1. Online delivery available in UAE , India

# %%
# Create a pie chart for zoamtro business per cities distribution
final_df.head(3)
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
#
#                                     Locality Verbose   Longitude   Latitude  \
# 0  Century City Mall, Poblacion, Makati City, Mak...  121.027535  14.565443
# 1  Little Tokyo, Legaspi Village, Makati City, Ma...  121.014101  14.553708
# ...

# %%
 final_df.City.value_counts()
# Out:
# New Delhi           5473
# Gurgaon             1118
# Noida               1080
# Faridabad            251
# Ghaziabad             25
#                     ...
# Panchkula              1
# Mc Millan              1
# Mayfield               1
# Macedon                1
# Vineland Station       1
# Name: City, Length: 141, dtype: int64

# %%
top_5_cities_index = final_df.City.value_counts().head(5).index
top_5_cities_index
# Out:
# Index(['New Delhi', 'Gurgaon', 'Noida', 'Faridabad', 'Ghaziabad'], dtype='object')

# %%
top_5_cities_values = final_df.City.value_counts().head(5).values
top_5_cities_values
# Out:
# array([5473, 1118, 1080,  251,   25], dtype=int64)

# %%
plt.pie(x = top_5_cities_values,labels=top_5_cities_index, autopct='%1.2f%%')
plt.show()

# %% [markdown]
# # Observations:
# 1. max transactions from New Delhi
# 2. followed by Gurgaon, noida, faridabad, ghaziabad
# 3. delhi cities comes in top5

# %%
#top 10 Cusinies
final_df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
final_df.Cuisines.value_counts().head(10)
# Out:
# North Indian                      936
# North Indian, Chinese             511
# Chinese                           354
# Fast Food                         354
# North Indian, Mughlai             334
# Cafe                              299
# Bakery                            218
# North Indian, Mughlai, Chinese    197
# Bakery, Desserts                  170
# Street Food                       149
# Name: Cuisines, dtype: int64

# %%
#cusinie
sns.countplot(final_df['Cuisines'].head(20))
sns.countplot(final_df['Cuisines'].head(20)).set_xticklabels(sns.countplot(final_df['Cuisines'].head(20)).get_xticklabels(), rotation=90, ha="right")
# Out:
# C:\Users\Snehal Sanap\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Snehal Sanap\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Snehal Sanap\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# ...

# %%
final_df.head(3)
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
#
#                                     Locality Verbose   Longitude   Latitude  \
# 0  Century City Mall, Poblacion, Makati City, Mak...  121.027535  14.565443
# 1  Little Tokyo, Legaspi Village, Makati City, Ma...  121.014101  14.553708
# ...

# %%
final_df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
#Restaurants delivering Online or not
sns.countplot(x= 'Has Online delivery', data=final_df)
plt.title('Restaurants delivering online or Not')
#most has no ol delivery
# Out:
# Text(0.5, 1.0, 'Restaurants delivering online or Not')

# %%
#Restaurants allowing table booking or not
sns.countplot(x= 'Has Table booking', data=final_df)
plt.title('Restaurants allowing table booking or not')
#most dont allow it
# Out:
# Text(0.5, 1.0, 'Restaurants allowing table booking or not')

# %%
pd.set_option('display.max_columns', None)
final_df.head(3)
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
#
#                                     Locality Verbose   Longitude   Latitude  \
# 0  Century City Mall, Poblacion, Makati City, Mak...  121.027535  14.565443
# 1  Little Tokyo, Legaspi Village, Makati City, Ma...  121.014101  14.553708
# ...

# %%
final_df.groupby(['Aggregate rating', 'Country']).size().unstack()
# Out:
# Country           Australia  Brazil  Canada   India  Indonesia  New Zealand  \
# Aggregate rating
# 0.0                     NaN     5.0     NaN  2139.0        NaN          NaN
# 1.8                     NaN     NaN     NaN     1.0        NaN          NaN
# 1.9                     NaN     NaN     NaN     2.0        NaN          NaN
# 2.0                     NaN     NaN     NaN     7.0        NaN          NaN
# 2.1                     NaN     NaN     NaN    15.0        NaN          NaN
# 2.2                     NaN     NaN     NaN    26.0        NaN          NaN
# 2.3                     NaN     NaN     NaN    46.0        NaN          1.0
# 2.4                     1.0     NaN     NaN    83.0        NaN          NaN
# 2.5                     NaN     NaN     NaN   109.0        NaN          NaN
# 2.6                     1.0     NaN     NaN   190.0        NaN          NaN
# 2.7                     NaN     NaN     NaN   250.0        NaN          NaN
# ...

# %%
#Cusine wise agg_rating
a = final_df.groupby(['Cuisines', 'Aggregate rating']).size().reset_index().rename({0:'count'}, axis=1).sort_values(by=['Aggregate rating', 'count'], ascending=False).head(20)
a
# Out:
#                                    Cuisines  Aggregate rating  count
# 3842                      Sunda, Indonesian               4.9      3
# 561                     Brazilian, Bar Food               4.9      2
# 1493                               Desserts               4.9      2
# 1618  European, Mediterranean, North Indian               4.9      2
# 2042                                 Indian               4.9      2
# 2573                          Modern Indian               4.9      2
# 2695                           North Indian               4.9      2
# 2764                  North Indian, Chinese               4.9      2
# 3052  North Indian, European, Mediterranean               4.9      2
# 31                  American, BBQ, Sandwich               4.9      1
# 68                  American, Burger, Grill               4.9      1
# 73             American, Caribbean, Seafood               4.9      1
# 77                 American, Coffee and Tea               4.9      1
# ...

# %%
#Most famous Restaurant chains 
plt.figure(figsize=(15,7))
chains=final_df['Restaurant Name'].value_counts()[:20]
sns.barplot(x=chains,y=chains.index,palette='Set1')
plt.title("Most famous restaurant chains",size=20,pad=20)
plt.xlabel("Number of outlets",size=15)
# Out:
# Text(0.5, 0, 'Number of outlets')
